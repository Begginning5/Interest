# %%
# This is a Journal of lab2 covering multicolinearity.

# %%
# import pandas as pd
# from statsmodels.forumla.api import ols
# path = 'C://path/'
# houses = pd.read_csv(path+'file.csv')
# houses.variable = house.variable.astype(str)
# house.shape
# house.describe()
# house.corr()
# house_model = ols("""dept_var ~ var1 + var2 + var1:var2""",data=table).fit()
# house.model.rsquared
# VIF = 1/(1-house_model.rsquared)
# house_model2.copy()
# vif = pd.DataFrame() 
# from sklearn.preprocessing import StandardScaler
#scaler = standardScaler()
# names = ['Var1','Var2','Var3','Var4']
# scaled_output = scaler.fit_transform(house[names])
# scaled_df = pd.DataFrame(scaled_output, columns = names)
# scaled_data.head()
# scaled_df.head()
# house_model = ols("""dept_var~var1+var2+var3+var4""", data=scaled_df).fit()
# house_model.summary() 
# house_model2.params
# area_tree = sk.treeDecisionTreeRegressor(max_depth=1)
# area_tree = area_tree.fit(X_Train,Y_Train)
# tree.plot_tree(area_year_tree2, feature_names=feature_cols)
# class_names = ['died', 'survived'], filled = True, precision=2, mode_ids=True, fontsize=12, lael='root', proportion=True, impurity=False)
# Total_Sale_Price~Heated_Area+Year_Of_Sale+C(Design_Style)+C(Physical_City)+C(Num_Stories)+C(Physical_City):C(Num_Stories)""", data=houses).fit()

# not sure how much of this last lab info I will beable to use.

# %%
# These Are the Functions used in Lab2.

##house_model.summary()
#house.dtypes()
#house2=house[house.city=='City1']
#house2.shape

#house2.rename(columns={'name':'business_name'},inplace=True)
#house2.head()

#rev1 = pd.read_csv(path+'yelp_review.csv',nrows=100)
#rev1.head()
#len(rev1.text[0])
# users1 = pd.read_csv(path+'yelp_user.csv',usecols=['user_id','name','review_count','yelping_since','average)stars'])
#char_rev1=pd.merge(rev1,char_bus1,on='business_id')
#char_rev2 = pd.merge(char_rev1,users1, on='user_id')
#char_rev2['date'] = pd.to_datetime(char_rev2.date)
# char_rev2['yelping_since'] = pd.to_datetime(char_rev2.yelping_since)
# char_rev2.head().T
# char_rev2['business_name']=char_rev2.business_name.strip('"')
# char_rev2.categories.value_counts()

# char_rev3.review_id.nunique()
# char_rev3.set_index('review_id',inplace=True)
# char_rev3.reset_index(inplace=True)
# char_rev3.head()

# review_count = pd.DataFrame(char_rev3.business_name.values_counts()).reset_index()
# review_count.columns
# char_rev3.groupby('user_id')
# group1 = char_rev3.groupby('user_id')

# users_agg = group1.agg({'stars':'mean','business_id':'nunique'})
# users_agg2 = group1.agg({'stars':['min','mean','max'],'business_id':'nunique'})
# users_agg2.columns = ['_'.join(col) for col in users_agg2.columns]

# func1 = lambda x: 'Good' if x>=3 else 'Bad'

# user_stars['rating'] = user_stars['stars'].apply(func1)
# user_stars['rating'] = user_stars['stars'].apply(lambda x: ' Good' if x>=3 else 'Bad')

#def func2(x):
   if x==1:
        return 'Bad'
    elif x <=4:
        return 'OK'
    else:
        return 'Excellent'

# user_stars['rating2'] = user_stars['stars'].apply(func2)

# def rating_groups(df):
#     if df['stars'] == 1:
#         return 'Bad'
#     elif df['stars'] == 'Bad':
#         return 'OK'
#     else:
#         return 'Fine'

# user_stars['rating3']= user_stars.apply(rating_groups, axis=1)
user_stars.head()

#user_stars_group = char_rev3.groupby(['user_id','rating'])
# user_stars2 = user_stars_group.agg({'review_id':'cout'}).reset_index()

# user_stars3 = user_stars2.pivot_table(index='user_id',columns='rating',values='review_id',fill_value=0)

# users_agg3 = users_agg2[users_agg2.business_id_nunique >= 10]
# users_agg4 = pd.merge(users_agg3,user_stars3, on='user_id')
# users_agg4.head()

#users_agg4['good_pct'] = users_agg4['Good'] / users_agg4.business_id_nunique
# users_agg5.reset_index(inplace=True)

# char_rev4 = pd.merge(char_rev3, users_agg5[['user_id']], on='user_id')
# char_rev4.to_csv(path+'file.csv')
# rev1 = pd.read_csv

# %%
# These are functions from Lab3

# titanic1.drop(columns=['name2','name3','name4'],inplace=True)
# titanic1.title.str.len().head()
# Titanic2.embarked.fillna('Avg',inplace=True)
# Titanic2['pclass'] = titanic2.pclass.astype(str)
# Titanic2.title.value_counts()

# %%
# These are the notes from Lab5

# titanic3 = pd.read_csv('titanic_cleaned.csv')
# titanic3 = pd.getdummies(titanic2)

# import sklearn as sk
# from sklearn.model_section import train_test_split

# from sklearn import metrics
# from sklearn import tree
# from sklearn.tree import DecisionTreeClassifier

# feature_cols = titanic3.drop('survived', axis=1).columns
# x = titanic3[feature_cols]
# y = titanic3.survived 

# X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3, random_state=1)
# ! python -m pip show scikit-learn
# ! pip install -U scikit-learn
# clf = tree.DecisionTreeClassifier(max_depth=2, class_weight='balanced')
# clf2 = clf.fit(X_train, Y_train)
# tree.plot_tree(clf2)
# tree.plot_tree(clf2, feature_names=feature_cols, class_names=['died','survived'], filled=True, precision=2, node_ids=True, fontsize=12, label='root',proportion=True, impurity=False)
# import matplotlib.pyplot as plt
# plt.figure(figsize=(15,7))
# tree.plot_tree(clf2, feature_names=feature_cols, class_names=['died

#clf2 = clf.fit(X_train, Y_train)
# y_pred = clf2.predict(x_test)
# metrics.accuracy_score(y_test, y_pred)
# metrics.confusion_matrix(y_test, y_pred)
# tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_pred).ravel()
# precision = tp / (tp + fp)
# precision 
# recall = tp/(tp+fn)
# recall
# clf = tree.DecisionTreeClassifier(max_depth=2, class_weight='balanced')
# clf2 = clf.fit(X_train,y_train)
# plt.figure(figsize=(15,7))
# tree.plot_tree(clf2, feature_names=feature_cols, class_names=['died','survived'], filled=True, precision=2, node_ids=True, fontsize=12, label='root', proportion=True, impurity=False)
# y_pred=clf2.predict(X_test)


#def run_model():
    clf = tree.DecisionTreeClassifier(max_depth=2, class_wieght='balanced', criterion='gini', splitter='best', min_samples_leaf=)

# %%
# Assignment 5

# df2= pd.get_dummies(df)
# df2.head().T
# feature_cols = df2.drop('IsBadBuy', axis=1).columns
# X = df2[feature_cols]
# Y = df2.IsBadBuy
# X_train, X_test, y_test = train_test_split(X,Y,test_size=0.3)
# clf = tree.DecisionTreeClassifier(max_depth=1,class_weight='balanced')
# clf2 = clf.fit(X_train, Y_train)
# fig = plt.figure(flagsize=(20,15))
# tree.plot_tree(clf2, feature_names = feature_cols, class_names=['good_buy','bad_buy'], filled=True, precision=2, node ids=True, fontsize=12, label='root', proportion=True, impurity=False)

# %%
clf = tree.DecisionTreeClassifier(max_depth=1, class_weight='balanced')
clf2 = clf.fit(x_train, y_train)
fig = plt.figure(figsize=(20,15))
tree.plot_tree(clf2, feature_names=feature_cols, class_names=['good_buy','bad_buy'], filled=True, precision=2, node_ids=True, precision=2, node_ids=True, fontsize=12, label='root', proportion=True, impurity=False)
y_pred=clf.predict(x_test)
print(metrics.classification_report(y_test, y_pred))
y_pred=clf2.predict(x_test)
print(metrics.classification_report(y_test, y_pred))

# %%
# BAS230 Assignment 1

# import pandas as pd 
# import numpy as np

# df = pd.read_csv(f'{path}/{file}')

# df = df.drop(['id', 'verification_status','issue_d'], axis=1)

emp_length = df['emp_length'].str.replace(r'[0-9]','',regex=True)
emp_length.value_counts()
emp_years = df['emp_length'].str.extract('(\d+)').astype(float)
emp_years.mean()
df['emp_length'].fillna('6 years', inplace=True)
timeframe = df['term'].str.extract('(\d+)').astype(float)


# import statsmodels.api as sm
# from statsmodels.forumla.api import ols
# import statsmodels.tools.eval_measures as sme
# import csv 
# import os

#filtered_data = df.select_dtypes(include='float64')
#filtered_data.corr()

# %%
# fpr, tpr, thresholds = skm.roc_curve(loans['defaulted'],loans['prob_default'])

# auc_score = skm.auc(fpr, tpr)

# import matplotlib.pyplot as plt

# def plot roc(fpr, tpr):
   # AUC score
#    auc_score = skm.auc(fpr, tpr)
   # ROC curve
#    skm.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=auc_score, estimator_name='results').plot()
   # Add the diagonal line 
#    plt.plot([0, 1],[0, 1], color='orange', linestyle='--')

# model2 = logit(formula = 'defaulted ~ C(term)', data = loans).fit()
